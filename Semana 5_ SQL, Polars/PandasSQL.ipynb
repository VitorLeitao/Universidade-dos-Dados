# %% [markdown]
# # Desafio
# Lembra do dataset da Olist que estamos trabalhando há algumas semanas?
# Que tal tratar aquelas tabelas utilizando SQL? Você pode usar o bigquery ou pandasql,
# ambos vão permitir que você use SQL no Python. Com isso, você pode unir tabelas,
# fazer limpezas e por aí vai, demonstrando ao recrutador seu conhecimento em SQL!

# %% [markdown]
# ![Vendas Relacional.png](data:image/png;base64,...)

# %%
## Importing pandasql
import pandasql as psql
import numpy as np
import pandas as pd

# %%
df_vendas = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_orders_dataset.csv')
df_clientes = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_customers_dataset.csv')
df_itens = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_order_items_dataset.csv')
df_pagamento = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_order_payments_dataset.csv')
df_review = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_order_reviews_dataset.csv')
df_vendedores = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_sellers_dataset.csv')
df_localizacao = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_geolocation_dataset.csv')
df_produtos = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 2/Dataset semana 2/olist_products_dataset.csv')

# %%
df_clientes.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Aplicando alguns selecs inicais

# %%
query = "SELECT * FROM df_clientes"

# Run the SQL query using sqldf function
sdf = psql.sqldf(query, locals())

# Print the first few rows of the result
print(sdf.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1407         try:
# -> 1408             meth = statement._execute_on_connection
#    1409         except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# <ipython-input-25-a69ecfbfacc5> in <cell line: 4>()
#       2
#       3 # Run the SQL query using sqldf function
# ----> 4 sdf = psql.sqldf(query, locals())
#       5
#       6 # Print the first few rows of the result
#
# /usr/local/lib/python3.10/dist-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
# ...
