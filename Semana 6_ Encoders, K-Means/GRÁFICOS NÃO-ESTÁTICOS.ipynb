# %% [markdown]
# # MATPLOTLIB INTERATIVO

# %%
# !pip install ipywidgets

# %%
# !pip install ipympl

# %%
# mudar as apresentações gráficas no Jupyter Notebook
# a primeira trabalha para apresentar os gráficos em frontends, como o Jupyter, enquanto a segunda serve para apresentar os widgets

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline
# %matplotlib widget

# %%
df = pd.read_csv('/content/drive/MyDrive/Universidade de dados/Semana 6/Fish.csv')
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
_ = plt.hist(df.Height)
_ = plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # PANDAS INTERATIVO

# %% [markdown]
# Para fazer graficos com pandas puro, mas usando a beleza do plotly, basta setar o backend do pandas para plotar com plotly

# %%
pd.options.plotting.backend = 'plotly'
# %matplotlib inline

# %%
df.Species.value_counts().plot(kind='bar')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.plot(x='Height', y='Weight', kind='scatter')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
